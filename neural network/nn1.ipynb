# %%
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
import random
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf

from numpy import save
from numpy import load

import matplotlib.pyplot as plt

# %%
X = load('C:/Users/Dindar/neural network/data50.npy')
y = load('C:/Users/Dindar/neural network/y50.npy')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X.T, y.reshape(24946,1), test_size=0.15, random_state=42)

# %%
x_train.shape
# Out:
# (21204, 7500)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import keras

# %%
# %%time
baseline_model = Sequential()
baseline_model.add(Dense(50,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros', input_shape=(7500,)))
baseline_model.add(tf.keras.layers.BatchNormalization())
baseline_model.add(Dense(35,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
baseline_model.add(tf.keras.layers.BatchNormalization())
baseline_model.add(Dense(20,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
baseline_model.add(tf.keras.layers.BatchNormalization())
baseline_model.add(Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))

baseline_model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),
              loss='binary_crossentropy', metrics=['accuracy'])

baseline_history = baseline_model.fit(x_train, y_train, epochs=400, batch_size=64,validation_data = (x_test, y_test))
# Out:
# Train on 21204 samples, validate on 3742 samples
# Epoch 1/400
# 21204/21204 [==============================] - 6s 271us/sample - loss: 0.7120 - accuracy: 0.5722 - val_loss: 0.6837 - val_accuracy: 0.5828
# Epoch 2/400
# 21204/21204 [==============================] - 3s 141us/sample - loss: 0.6466 - accuracy: 0.6238 - val_loss: 0.6557 - val_accuracy: 0.6138
# Epoch 3/400
# 21204/21204 [==============================] - 3s 126us/sample - loss: 0.6207 - accuracy: 0.6489 - val_loss: 0.6678 - val_accuracy: 0.6021
# Epoch 4/400
# 21204/21204 [==============================] - 3s 151us/sample - loss: 0.6014 - accuracy: 0.6676 - val_loss: 0.6596 - val_accuracy: 0.6117
# Epoch 5/400
# 21204/21204 [==============================] - 2s 86us/sample - loss: 0.5920 - accuracy: 0.6811 - val_loss: 0.7013 - val_accuracy: 0.6053
# Epoch 6/400
# 21204/21204 [==============================] - 2s 87us/sample - loss: 0.5769 - accuracy: 0.6925 - val_loss: 0.6533 - val_accuracy: 0.6325
# Epoch 7/400
# ...

# %%
baseline_model.save('C:/Users/Dindar/neural network/baseline_model.h5')

# %%
# %%time
smaller_model = Sequential()
smaller_model.add(Dense(35,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros', input_shape=(7500,)))
smaller_model.add(tf.keras.layers.BatchNormalization())
smaller_model.add(Dense(25,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
smaller_model.add(tf.keras.layers.BatchNormalization())
smaller_model.add(Dense(10,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
smaller_model.add(tf.keras.layers.BatchNormalization())
smaller_model.add(Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))

smaller_model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),
              loss='binary_crossentropy', metrics=['accuracy'])

smaller_history = smaller_model.fit(x_train, y_train, epochs=400, batch_size=64,validation_data = (x_test, y_test))
# Out:
# Train on 21204 samples, validate on 3742 samples
# Epoch 1/400
# 21204/21204 [==============================] - 5s 214us/sample - loss: 0.6940 - accuracy: 0.5823 - val_loss: 0.7679 - val_accuracy: 0.5227
# Epoch 2/400
# 21204/21204 [==============================] - 2s 89us/sample - loss: 0.6448 - accuracy: 0.6229 - val_loss: 0.6563 - val_accuracy: 0.6162
# Epoch 3/400
# 21204/21204 [==============================] - 2s 87us/sample - loss: 0.6246 - accuracy: 0.6418 - val_loss: 0.6412 - val_accuracy: 0.6187
# Epoch 4/400
# 21204/21204 [==============================] - 2s 98us/sample - loss: 0.6092 - accuracy: 0.6616 - val_loss: 0.6554 - val_accuracy: 0.5959
# Epoch 5/400
# 21204/21204 [==============================] - 2s 98us/sample - loss: 0.6013 - accuracy: 0.6719 - val_loss: 0.7178 - val_accuracy: 0.5756
# Epoch 6/400
# 21204/21204 [==============================] - 4s 176us/sample - loss: 0.5864 - accuracy: 0.6833 - val_loss: 0.6302 - val_accuracy: 0.6344
# Epoch 7/400
# ...

# %%
smaller_model.save('C:/Users/Dindar/neural network/smaller_model.h5')

# %%
# %%time
bigger_model = Sequential()
bigger_model.add(Dense(300,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros', input_shape=(7500,)))
bigger_model.add(tf.keras.layers.BatchNormalization())
bigger_model.add(Dense(225,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
bigger_model.add(tf.keras.layers.BatchNormalization())
bigger_model.add(Dense(70,activation='relu',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))
bigger_model.add(tf.keras.layers.BatchNormalization())
bigger_model.add(Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform',
    bias_initializer='zeros'))

bigger_model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),
              loss='binary_crossentropy', metrics=['accuracy'])

bigger_history = bigger_model.fit(x_train, y_train, epochs=400, batch_size=512,validation_data = (x_test, y_test))
# Out:
# Train on 21204 samples, validate on 3742 samples
# Epoch 1/400
# 21204/21204 [==============================] - 2s 110us/sample - loss: 0.7069 - accuracy: 0.5947 - val_loss: 0.6872 - val_accuracy: 0.5513
# Epoch 2/400
# 21204/21204 [==============================] - 1s 34us/sample - loss: 0.6054 - accuracy: 0.6665 - val_loss: 0.6591 - val_accuracy: 0.6045
# Epoch 3/400
# 21204/21204 [==============================] - 1s 34us/sample - loss: 0.5619 - accuracy: 0.7103 - val_loss: 0.6335 - val_accuracy: 0.6323
# Epoch 4/400
# 21204/21204 [==============================] - 1s 35us/sample - loss: 0.5225 - accuracy: 0.7415 - val_loss: 0.6733 - val_accuracy: 0.5941
# Epoch 5/400
# 21204/21204 [==============================] - 1s 33us/sample - loss: 0.4970 - accuracy: 0.7595 - val_loss: 0.6554 - val_accuracy: 0.6208
# Epoch 6/400
# 21204/21204 [==============================] - 1s 33us/sample - loss: 0.4608 - accuracy: 0.7911 - val_loss: 0.7582 - val_accuracy: 0.5975
# Epoch 7/400
# ...

# %%
bigger_model.save('C:/Users/Dindar/neural network/bigger_model.h5')

# %%
bigger_model.evaluate(x_test, y_test)
# Out:
# 3742/3742 [==============================] - 0s 82us/sample - loss: 1.8854 - accuracy: 0.6507
# [1.8854420823505509, 0.65072155]

# %%
def plot_history(histories, key='accuracy'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                               '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
                         label=name.title()+' Train')

    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])

# %%
plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])
